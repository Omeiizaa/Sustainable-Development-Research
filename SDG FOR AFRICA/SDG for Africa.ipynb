# %% [markdown]
# <center>
#     <div style="font-family: Garamond; font-size: 25px; font-weight: bold; color: black;">
#         COMPARATIVE ANALYSIS OF INFRASTRUCTURE AND ECONOMIC GROWTH IN SELECTED AFRICAN COUNTRIES
#     </div>
# </center>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px; color: #007acc; font-family: Garamond; font-weight: bold">
#     INTRODUCTION:
# </div>
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
#     This project aims to examine the relationship between infrastructure and economic growth across African nations, focusing on Nigeria. We will concentrate on Sustainable Development Goal (SDG) 9: Industry, Innovation, and Infrastructure and SDG 8: Decent Work and Economic Growth. Byanalyzing historical SDG scores from 2000 to 2022, this study seeks to uncover patterns and trends that may reveal whether improvements in infrastructure and innovation are correlated with economic growth in Africa.
# Exploring SDG 9 allows us to understand the progress in developing robust industrial and infrastructure systems essential for enhancing connectivity and supporting sustainable development. SDG 8, on the other hand, sheds light on economic opportunities, employment, and productivity as indicators of financial health. Through this comparative analysis, we anticipate discovering measurable links between infrastructure development and economic outcomes, offering insight into the effectiveness of infrastructure-focused strategies in boosting economic growth. The results aim to inform policymakers and stakeholders on the importance of targeted investment in infrastructure to foster economic resilience and sustainability across Africa.
# The methodology involves two key approaches: correlation analysis and trend analysis over time. Correlation analysis will identify potential statistical relationships between SDG 9 and SDG 8 scores, indicating whether and how strongly infrastructure improvements relate to economic growth. Meanwhile, trend analysis over the years 2000 to 2022 will highlight the progress and shifts in these SDGs, particularly in Nigeria and other selected African countries. This combined approach offers a comprehensive view of infrastructure and economic trends, providing valuable insights for future development strategies
# </div>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px; color: #007acc; font-family: Garamond; font-weight: bold">
#     DATA DESCRIPTION:
# </div>
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
#     The SDG dataset used in this analysis, sourced from Kaggle, covers annual Sustainable Development Goal (SDG) scores from 2000 to 2022 for over 100 countries worldwide, including a significant representation of African nations. Each country's scores across the 17 SDGs provide a measure of progress in areas such as economic growth, infrastructure, education, health, and environmental sustainability. This dataset is particularly well-suited for understanding regional development trends, as it allows us to track specific SDG scores that directly impact economic stability and quality of life. The availability of data across various countries enables comparative analysis, providing context for understanding Nigeria's development trends relative to African counterparts. This makes the dataset a powerful tool for exploring the region's challenges and advancements, helping to identify patterns that may inform future policy and investment decisions in sustainable development.
# </div>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px; color: #007acc; font-family: Garamond; font-weight: bold">
#     IMPORTING LIBRARIES AND DATAFRAME:
# </div>

# %%
#Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Importing the dataset which has been downloaded to my PC from Kaggle
df = pd.read_csv("C:/Users/HP/OneDrive/Documents/PYTHON/PANDAS/DATABASES/sdg_index_2000-2022.csv")

#To display the first few rows of the dataset to understand its structure
df.head()
# Out:
#   country_code      country  year  sdg_index_score  goal_1_score  \
# 0          AFG  Afghanistan  2000             36.0          28.8
# 1          AFG  Afghanistan  2001             36.3          28.8
# 2          AFG  Afghanistan  2002             36.3          28.8
# 3          AFG  Afghanistan  2003             36.7          28.8
# 4          AFG  Afghanistan  2004             37.1          28.8
#
#    goal_2_score  goal_3_score  goal_4_score  goal_5_score  goal_6_score  ...  \
# 0          27.3          19.2           1.6          20.8          32.4  ...
# 1          30.6          19.4           1.6          20.8          32.4  ...
# 2          30.7          19.7           1.6          20.8          32.7  ...
# 3          32.5          19.9           1.6          20.8          33.0  ...
# 4          32.1          21.1           1.6          20.8          33.3  ...
#
#    goal_8_score  goal_9_score  goal_10_score  goal_11_score  goal_12_score  \
# ...

# %% [markdown]
# <div style="text-align: justify; font-size: 20px; color: #007acc; font-family: Garamond; font-weight: bold">
#     INFORMATION ABOUT THE DATAFRAME:
# </div>

# %% [markdown]
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
#     Here is some information about the dataset including column names and data types. We can also see there are no null cells. So the dataframe is fit to start analysing
# </div

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4140 entries, 0 to 4139
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country_code     4140 non-null   object
#  1   country          4140 non-null   object
#  2   year             4140 non-null   int64
#  3   sdg_index_score  4140 non-null   float64
#  4   goal_1_score     4140 non-null   float64
#  5   goal_2_score     4140 non-null   float64
#  6   goal_3_score     4140 non-null   float64
#  7   goal_4_score     4140 non-null   float64
#  8   goal_5_score     4140 non-null   float64
#  9   goal_6_score     4140 non-null   float64
#  10  goal_7_score     4140 non-null   float64
#  11  goal_8_score     4140 non-null   float64
#  12  goal_9_score     4140 non-null   float64
#  13  goal_10_score    4140 non-null   float64
#  14  goal_11_score    4140 non-null   float64
#  15  goal_12_score    4140 non-null   float64
# ...

# %% [markdown]
# <div style="text-align: justify; font-size: 20px; color: #007acc; font-family: Garamond; font-weight: bold">
#     FILTERING:
# </div>
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
#     Selecting relevant columns for the analysis since we are focusing on SDG 8 and SDG 9. I then filtered data for 5 African Countries for the purpose of this analysis.
# </div>

# %%
Required_SDGs = ['country', 'year', 'goal_8_score', 'goal_9_score']
df_Required = df[Required_SDGs]
df_Required
# Out:
#           country  year  goal_8_score  goal_9_score
# 0     Afghanistan  2000          38.5           5.2
# 1     Afghanistan  2001          38.5           5.2
# 2     Afghanistan  2002          38.4           5.2
# 3     Afghanistan  2003          38.4           5.2
# 4     Afghanistan  2004          38.5           5.2
# ...           ...   ...           ...           ...
# 4135     Zimbabwe  2018          63.8          23.5
# 4136     Zimbabwe  2019          62.8          23.8
# 4137     Zimbabwe  2020          62.9          25.4
# 4138     Zimbabwe  2021          63.1          27.0
# 4139     Zimbabwe  2022          63.2          27.0
#
# [4140 rows x 4 columns]

# %%
selected_countries = ['Nigeria', 'Kenya', 'South Africa', 'Ghana', 'Morocco']
df_selected_africa = df_Required[df_Required['country'].isin(selected_countries)]

# %%
df_selected_africa
# Out:
#            country  year  goal_8_score  goal_9_score
# 1426         Ghana  2000          68.0          16.7
# 1427         Ghana  2001          68.5          16.7
# 1428         Ghana  2002          69.0          16.7
# 1429         Ghana  2003          69.6          16.7
# 1430         Ghana  2004          70.1          16.7
# ...            ...   ...           ...           ...
# 3422  South Africa  2018          67.0          64.5
# 3423  South Africa  2019          67.1          69.6
# 3424  South Africa  2020          68.1          70.1
# 3425  South Africa  2021          69.8          70.8
# 3426  South Africa  2022          69.8          70.8
#
# [115 rows x 4 columns]

# %% [markdown]
# <div style="text-align: justify; font-size: 20px; color: #007acc; font-family: Garamond; font-weight: bold">
#     DESCRIPTIVE STATISTICS:
# </div>
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
#     Calculating basic statistics for SDG 8 and SDG 9 scores across the 5 selected countries
# </div>

# %%
descriptive_stats = df_selected_africa.groupby('country')[['goal_8_score', 'goal_9_score']].agg(['mean', 'median', 'std', 'min','max'])
descriptive_stats
# Out:
#              goal_8_score                              goal_9_score         \
#                      mean median       std   min   max         mean median
# country
# Ghana           71.965217   71.2  2.435459  68.0  76.4    25.839130   19.4
# Kenya           73.300000   71.5  2.431049  71.3  77.1    19.143478   14.1
# Morocco         70.356522   70.6  1.232081  67.4  71.7    36.152174   34.0
# Nigeria         63.943478   62.5  1.892047  62.4  67.0    21.721739   17.0
# South Africa    66.839130   66.6  1.311051  64.6  69.8    55.482609   52.0
#
#
#                     std   min   max
# country
# Ghana         11.274055  16.7  46.8
# Kenya          9.474023  11.6  39.2
# Morocco        9.922100  25.1  55.1
# Nigeria        8.937661  15.0  40.6
# South Africa   9.378876  45.8  70.8

# %% [markdown]
# <div style="text-align: justify; font-size: 20px; color: #007acc; font-family: Garamond; font-weight: bold">
#     VISUALIZATION TRENDS:
# </div>
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
#     Visualized trends in SDG 8 and 9 over time for these selected countries
# </div>

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(20, 10))

#For SDG 8
plt.subplot(2,1,1) 
sns.lineplot(data=df_selected_africa, x='year', y='goal_8_score', hue='country', marker='o')
plt.title('Trend of SDG 8 (Economic Growth) over time', fontsize=28, fontweight='bold')
plt.xlabel('Year', fontsize=20, fontweight='bold')
plt.ylabel('SDG 8 score', fontsize=20, fontweight='bold')
plt.legend(title='country')

#For SDG 9
plt.subplot(2,1,2)
sns.lineplot(data=df_selected_africa, x='year', y='goal_9_score', hue='country', marker='o')
plt.title('Trend of SDG 9(Infrastructure development) over time', fontsize=28, fontweight='bold')
plt.xlabel('Year', fontsize=20, fontweight='bold')
plt.ylabel('SDG 9 score', fontsize=20, fontweight='bold')
plt.legend(title='country')
plt.tight_layout()

plt.show()

# %% [markdown]
# <div style="text-align: justify; font-size: 20px; color: #007acc; font-family: Garamond; font-weight: bold">
#     INTERPRETATION:
# </div>
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
# The line charts display the SDG 8(Decent Work and Economic Growth) and SDG 9 (Industry, Innovation, and Infrastructure) scores for selected African countries from 2000 to 2022. These trends reveal differences in economic and infrastructure progress across the countries studied, as highlighted below;
# For SDG 8, Ghana and Kenya maintained higher mean scores of 71.97 and 73.3 respectively compared too Nigeria(63.94). These scores indicate that Ghana and kemya have experienced relatively steady levels of economic growth, likely due o improvements in employment, productivity, and economic policies. Nigeria also shows a somewhat lower median score(62.5) with a standard deviation of 1.89, indicating less fluctuation but generally lower scores compared to peers, suggesting ongoing economic challenges.
# </div>

# %% [markdown]
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
# For SDG 9 on the other hand, South Africa leads in SDG 9 with the highes mean score of 55.54 and a median of 52, reflecting its significant investment in infrastructure. Morocco follows with a mean score of 36.15, indicating a relatively strong focus on infrstructure and innovation compared to other African counntries. Nigeria and Kenya have comparatively lower scores in SDG 9, with means of 21.72 and 19.14, respectively, and medians of 17.0 and 14.1. This may indicate room for growth in infrastructure that could support economic development and innovation.
# This analysis suggests a potential correlation between strong infrastructure scores and steady economic growth. Countries like South Africa and Morocco appear to experience more balanced scores across both SDGs, which may indicate a linkage between investment in infrastructure and economic resilience. On the other hand, Nigeria has a lower infrastructure score (SDG 9) relative to its economic growth score (SDG 8), hinting that economic initiatives may not be fully supported by equivalent infrastructure improvements. This disparity may point to areas where additional infrastructure investment could further stimulate economic development
# </div>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px; color: #007acc; font-family: Garamond; font-weight: bold">
#     CORRELATION:
# </div>
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
# Finding the correlation coefficient of SDG 8 and 9 using Pearson.
# </div>

# %%
correlation_results = {}

for country, data in df_selected_africa.groupby('country'):
    correlation = data['goal_8_score'].corr(data['goal_9_score'], method='pearson')

    correlation_results[country] = correlation
    print(f"{country} - Correlation between SDG 8 and SDG 9: {correlation:.2f}")
# Out:
# Ghana - Correlation between SDG 8 and SDG 9: 0.91
# Kenya - Correlation between SDG 8 and SDG 9: 0.83
# Morocco - Correlation between SDG 8 and SDG 9: -0.58
# Nigeria - Correlation between SDG 8 and SDG 9: 0.85
# South Africa - Correlation between SDG 8 and SDG 9: 0.62

# %%
# I made the correlation data into a dataframe for easier visualiztion.
correlation_df = pd.DataFrame(list(correlation_results.items()), columns=['country', 'r'])
print("\nCorrelation Coefficients between SDG 8 and SDG 9 scores by Country:")
correlation_df
# Out:
# Correlation Coefficients between SDG 8 and SDG 9 scores by Country:
#         country         r
# 0         Ghana  0.906163
# 1         Kenya  0.826722
# 2       Morocco -0.580889
# 3       Nigeria  0.853151
# 4  South Africa  0.619393

# %% [markdown]
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
# To find any strong correlations
# </div>

# %%
strong_correlations = correlation_df[correlation_df['r'].abs() >= 0.5]
print("\nCountries with Strong Correlation between SDG 8 and SDG 9 Scores:")
print(strong_correlations)
# Out:
# Countries with Strong Correlation between SDG 8 and SDG 9 Scores:
#         country         r
# 0         Ghana  0.906163
# 1         Kenya  0.826722
# 2       Morocco -0.580889
# 3       Nigeria  0.853151
# 4  South Africa  0.619393

# %% [markdown]
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
# From the above, it can be seen that there is a strong correlation between SDG 8 and 9 both positive and negative as it returned all the coutries. The following heatmap shows the significance level for each country.
# </div>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px; color: #007acc; font-family: Garamond; font-weight: bold">
#     VISUALIZATION: HEATMAP
# </div>
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
# Visual of how strong the relationship between SDG 8  and 9 is across the selected countries
# </div>

# %%
# Heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_df.set_index('country').T, 
            annot=True, 
            cmap='coolwarm', 
            center=0, 
            cbar=True)
plt.title('Correlation between SDG 8 and SDG 9 Scores by Country', fontsize = 15, fontweight = 'bold')
plt.show()

# %% [markdown]
# <div style="text-align: justify; font-size: 20px; color: #007acc; font-family: Garamond; font-weight: bold">
#     INTERPRETATION:
# </div>
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
# Ghana, Kenya, Nigeria, and South Africa all show strong positive correlations between SDG 8 and SDG 9 scores. This suggests a close alignment in the progression of economic growth and infrastructure improvements in these countries. The positive values indicate that advancements in infrastructure (e.g., access to industry, innovation, and basic infrastructure like roads and electricity) are associated with improvements in economic growth (such as employment and productivity). These results may imply that investments in infrastructure in these countries could yield significant economic benefits, supporting policies that prioritize infrastructure development as a foundation for economic growth
# </div>

# %% [markdown]
# <div style="text-align: justify; font-size: 16px; color: #000000; font-family: Garamond;">
# Morocco's correlation between SDG 8 and SDG 9 is moderately negative, indicating an inverse relationship. This suggests that periods of infrastructure improvement did not correspond to proportional economic growth or may have occurred during economic downturns. The negative correlation may reflect unique contextual factors in Morocco. This pattern indicates a need for targeted research to explore why infrastructure investment and economic growth do not align in Morocco as they do in other African nations. It may also suggest that alternative economic or infrastructural factors should be prioritized to better achieve SDG targets.</div>
